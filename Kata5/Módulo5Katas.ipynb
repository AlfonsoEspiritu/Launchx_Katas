# %% [markdown]
# 1 - Utilizar operadores aritméticos

# %%
Tierra = 149597870
Jupiter = 778547200

# %%
Dkm = Tierra -  Jupiter
print("La ditancia en kilometros es: "+str(Dkm))

Millas = Dkm*0.621
print("La distancia entre millas es: "+str(Millas))
# Out:
# La ditancia en kilometros es: -628949330
# La distancia entre millas es: -390577533.93

# %% [markdown]
# 2 -convierte cadenas en números y usa valores absolutos

# %%
Tierra = input("Cual es la distancia del sol a la tierra en km")
Marte = input("Cual es la distancia del sol a Marte en km")

# %%
Tierra = int(149600000)
Marte = int(227900000)

# %%
dkm = Tierra-Marte
print('La deistancia en kilometros es: '+ str(dkm))
millas = dkm*0.621
print('La deistancia en kilometros es: '+ str(millas))
# Out:
# La deistancia en kilometros es: -78300000
# La deistancia en kilometros es: -48624300.0
