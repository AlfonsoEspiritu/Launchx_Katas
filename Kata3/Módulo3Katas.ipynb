# %% [markdown]
# ## Condicionales if, else, y elif

# %%
asteroide = 49
if asteroide >25:
    print( "!! ADVERTENCIA !! Un asteroide se aproxima a la tierra!!")
else:
    print("Todo se encuentra bein")
# Out:
# !! ADVERTENCIA !! Un asteroide se aproxima a la tierra!!

# %%
asteroide = 19
if asteroide > 20:
    print("El rayo que emite el asteroide se puede ver")
elif asteroide == 20:
    print("El rayo que emite el asteroide se puede ver")
else:
    print("No se aprecia el rayo del asteroide")
# Out:
# No se aprecia el rayo del asteroide

# %% [markdown]
# ## Uso de operadores and y or

# %%
velocidad_asteroide = 25
tamano_asteroide = 40
if velocidad_asteroide > 25 and tamano_asteroide > 25:
    print(" !!ADVERTENCIA!!,  Un asteroide muy peligroso viene hacia la Tierra ")
elif velocidad_asteroide >= 20:
    print("El rayo que emite el asteroide se puede ver")
elif tamano_asteroide < 25:
    print(" Nada se aprecia nada por el momento ")
else:
    print(" Nada se aprecia nada por el momento ")
# Out:
# El rayo que emite el asteroide se puede ver
